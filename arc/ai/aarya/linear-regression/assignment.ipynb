# %% [markdown]
# # Linear Regression Analysis
#
# ---
#
# ## Univariate Linear Regression (Scratch)
#
# - Implement univariate linear regression from scratch using Salary Data.
# - Perform data wrangling and exploratory data analysis (EDA).
# - Split data into train/test sets (use `sklearn` for splitting only).
# - Evaluate the model with metrics computed from scratch.
#
# ---
#
# ## Evaluation Metrics (Scratch)
#
# - Calculate all evaluation metrics (e.g., MSE, R-squared, MAE) from scratch for the trained model.
#
# ---
#
# ## Sklearn Comparison
#
# - Train linear regression using `sklearn` on Salary Data.
# - Compute evaluation metrics.
# - Compare results with the scratch implementation.
#
# ---
#
# ## Housing Price Prediction (Sklearn)
#
# - Use the Housing Price dataset to fit a regression model with `sklearn`.
# - Preprocess data and perform EDA.
# - Evaluate the model and visualize findings.
# - Identify key features impacting housing prices.

# %%
msg = "Hello world"
print(msg)
# Out:
# Running cells with 'Python 3.13.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
