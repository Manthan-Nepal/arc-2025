# %% [markdown]
# 2. Create an empty data dictionary with keys: name, roll, address, age where all the keys store a list of values. Fill in 10 valid data samples in the dictionary asking from the user. Then convert the dictionary to dataframe and add a new column to the dataframe called ‘category’. If the age is less than or equal to 15 then, category will be ‘Junior’, if its between 15 to 25(included), category will be ‘Mid’ and for the rest - category will be ‘Senior’. Display the dataframe. Calculate the average age and most frequent category.

# %%
import pandas as pd

# %%
data = {
    'name': [],
    'roll': [],
    'address': [],
    'age': []
}

# %%
for i in range(10):
    print(f"\nEnter details for student {i+1}:")
    name = input("Name: ")
    roll = input("Roll Number: ")
    address = input("Address: ")
    while True:
        try:
            age = int(input("Age: "))
            break
        except ValueError:
            print("Please enter a valid number for age.")
            
    data['name'].append(name)
    data['roll'].append(roll)
    data['address'].append(address)
    data['age'].append(age)
# Out:
# Enter details for student 1:
#
# Enter details for student 2:
#
# Enter details for student 3:
#
# Enter details for student 4:
#
# Enter details for student 5:
#
# Enter details for student 6:
#
# Enter details for student 7:
#
# Enter details for student 8:
#
# Enter details for student 9:
#
# Enter details for student 10:

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       name roll    address  age
# 0    Binay    1        Ktm   22
# 1  Kritika    2   Lazimpat   22
# 2    Yechu    3    Phutung    3
# 3    Banid    5   Hadigaun   23
# 4    Smiti    9   Kuleshor   22
# 5    Ashim    7   Lalitpur   23
# 6   Shailu   66     Dharan   21
# 7    Roman   77  Bhaktapur   23
# 8    Sohil   88    Srikali   33
# 9  Dikshit   12   Kisipide   20

# %%
def get_category(age):
    if age <= 15:
        return 'Junior'
    elif 15 < age <= 25:
        return 'Mid'
    else:
        return 'Senior'

df['category'] = df['age'].apply(get_category)

# %%
print("\nFinal DataFrame:")
print(df)
# Out:
# Final DataFrame:
#       name roll    address  age category
# 0    Binay    1        Ktm   22      Mid
# 1  Kritika    2   Lazimpat   22      Mid
# 2    Yechu    3    Phutung    3   Junior
# 3    Banid    5   Hadigaun   23      Mid
# 4    Smiti    9   Kuleshor   22      Mid
# 5    Ashim    7   Lalitpur   23      Mid
# 6   Shailu   66     Dharan   21      Mid
# 7    Roman   77  Bhaktapur   23      Mid
# 8    Sohil   88    Srikali   33   Senior
# 9  Dikshit   12   Kisipide   20      Mid

# %%
average_age = df['age'].mean()
most_frequent_category = df['category'].mode()[0]

print(f"\nAverage Age: {average_age}")
print(f"Most Frequent Category: {most_frequent_category}")
# Out:
# Average Age: 21.2
# Most Frequent Category: Mid

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   roll      10 non-null     object
#  2   address   10 non-null     object
#  3   age       10 non-null     int64
#  4   category  10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes
