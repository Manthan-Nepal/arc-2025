# %%
import pandas as pd
import numpy as np

# %%
# creating an empty dicitionary
dict_data = {
    'name' : [],
    'roll' : [],
    'address' : [],
    'age' : []
}

# %%
# Ask User for 10 valid inputs

for i in range(10):
    print(f"Enter details for the {i+1}th student :\n")
    name = input("Enter the name\n")
    roll = input("Enter the roll no\n")
    address = input("Enter the address\n")
    
    while True:
        try:
            age = int(input("Enter the age\n"))
            break
        except ValueError:
            print("Please enter the valid age")
    
    dict_data['name'].append(name)
    dict_data['roll'].append(roll)
    dict_data['address'].append(address)
    dict_data['age'].append(age)
# Out:
# Enter details for the 1th student :
#
# Enter the name
# Arjun
# Enter the roll no
# 34
# Enter the address
# tilottama
# Enter the age
# 34
# Enter details for the 2th student :
#
# Enter the name
# fgsd
# Enter the roll no
# 23
# Enter the address
# butwal
# Enter the age
# 13
# Enter details for the 3th student :
#
# Enter the name
# anju
# Enter the roll no
# 34
# Enter the address
# tilottama
# Enter the age
# 23
# Enter details for the 4th student :
#
# Enter the name
# gita
# Enter the roll no
# 34
# Enter the address
# dalkjs
# Enter the age
# 23
# Enter details for the 5th student :
#
# Enter the name
# kristian
# Enter the roll no
# 343
# Enter the address
# dahg
# Enter the age
# 34
# Enter details for the 6th student :
#
# Enter the name
# bhim
# Enter the roll no
# 3343
# Enter the address
# dada
# Enter the age
# 24
# Enter details for the 7th student :
#
# Enter the name
# partb
# Enter the roll no
# 343
# Enter the address
# dhfa
# Enter the age
# 343
# Enter details for the 8th student :
#
# Enter the name
# risita
# Enter the roll no
# 343
# Enter the address
# ajhg
# Enter the age
# 23
# Enter details for the 9th student :
#
# Enter the name
# dikshya
# Enter the roll no
# 434
# Enter the address
# dsafd
# Enter the age
# 34
# Enter details for the 10th student :
#
# Enter the name
# surya
# Enter the roll no
# 343
# Enter the address
# dfa
# Enter the age
# 23

# %%
df = pd.dataframe()
df['category'] = df['age'].apply(
    lambda age: 'Junior' if age <= 15 else 'Mid' if age <= 25 else 'Senior'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.dataframe()
#       2 df['category'] = df['age'].apply(
#       3     lambda age: 'Junior' if age <= 15 else 'Mid' if age <= 25 else 'Senior'
#       4 )
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
print("The dataframe is :")
print(df)

# calculate the average of the age

avg_age = df['age'].mean()
print(f"The average age is {avg_age}\n")

# Calculate the most frequent category

most_fre_category = df['category'].mode()[0]
print(f"The most frequent category is {most_fre_category}")
