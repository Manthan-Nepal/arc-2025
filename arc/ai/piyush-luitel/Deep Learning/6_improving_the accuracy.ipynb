# %% [markdown]
# https://docs.pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html

# %% [markdown]
#  For the quickstart resource of Pytorch given in the above link, the accuracy there is 50%. Your task is to boost the accuracy above 78%. Do not use transfer learning. Make sure there is no overfitting by plotting the train and test loss.
