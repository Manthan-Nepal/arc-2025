# %% [markdown]
# ### Resources:
#
# - https://www.ibm.com/think/topics/natural-language-processing
# - https://www.ibm.com/think/topics/natural-language-processing
# - https://www.scaler.com/topics/nlp/text-representation-in-nlp/
# -

# %% [markdown]
# # NLP
#
# Natural language processing (NLP) is a subfield of computer science and artificial intelligence (AI) that uses machine learning to enable computers to understand and communicate with human language.
#
# ### Benefits of NLP
# NLP makes it easier for humans to communicate and collaborate with machines, by allowing them to do so in the natural human language they use every day. This offers benefits across many industries and applications.
#
# - Automation of repetitive tasks
# - Improved data analysis and insights
# - Enhanced search
# - Content generation

# %% [markdown]
# ### Approaches to NLP
#
# NLP combines the power of computational linguistics together with machine learning algorithms and deep learning. Computational linguistics uses data science to analyze language and speech. It includes two main types of analysis: syntactical analysis and semantical analysis. Syntactical analysis determines the meaning of a word, phrase or sentence by parsing the syntax of the words and applying preprogrammed rules of grammar. Semantical analysis uses the syntactic output to draw meaning from the words and interpret their meaning within the sentence structure.
#
# The parsing of words can take one of two forms. Dependency parsing looks at the relationships between words, such as identifying nouns and verbs, while constituency parsing then builds a parse tree (or syntax tree): a rooted and ordered representation of the syntactic structure of the sentence or string of words. The resulting parse trees underly the functions of language translators and speech recognition. Ideally, this analysis makes the output either text or speech understandable to both NLP models and people.
#
# Self-supervised learning (SSL) in particular is useful for supporting NLP because NLP requires large amounts of labeled data to train AI models. Because these labeled datasets require time-consuming annotation, a process involving manual labeling by humans, gathering sufficient data can be prohibitively difficult. Self-supervised approaches can be more time-effective and cost-effective, as they replace some or all manually labeled training data.
#
# Three different approaches to NLP include:
#
# #### Rules-based NLP
# The earliest NLP applications were simple if-then decision trees, requiring preprogrammed rules. They are only able to provide answers in response to specific prompts, such as the original version of Moviefone, which had rudimentary natural language generation (NLG) capabilities. Because there is no machine learning or AI capability in rules-based NLP, this function is highly limited and not scalable.
#
# #### Statistical NLP
# Developed later, statistical NLP automatically extracts, classifies and labels elements of text and voice data and then assigns a statistical likelihood to each possible meaning of those elements. This relies on machine learning, enabling a sophisticated breakdown of linguistics such as part-of-speech tagging.
#
# Statistical NLP introduced the essential technique of mapping language elements, such as words and grammatical rules to a vector representation so that language can be modeled by using mathematical (statistical) methods, including regression or Markov models. This informed early NLP developments such as spellcheckers and T9 texting (Text on 9 keys, to be used on Touch-Tone telephones).

# %% [markdown]
# #### Deep learning NLP
# Recently, deep learning models have become the dominant mode of NLP, by using huge volumes of raw, unstructured data both text and voice to become ever more accurate. Deep learning can be viewed as a further evolution of statistical NLP, with the difference that it uses neural network models. There are several subcategories of models:
#
# Sequence-to-Sequence (seq2seq) models: Based on recurrent neural networks (RNN), they have mostly been used for machine translation by converting a phrase from one domain (such as the German language) into the phrase of another domain (such as English).
#
# Transformer models: They use tokenization of language (the position of each token words or subwords) and self-attention (capturing dependencies and relationships) to calculate the relation of different language parts to one another. Transformer models can be efficiently trained by using self-supervised learning on massive text databases. A landmark in transformer models was Google’s bidirectional encoder representations from transformers (BERT), which became and remains the basis of how Google’s search engine works.
#
# Autoregressive models: This type of transformer model is trained specifically to predict the next word in a sequence, which represents a huge leap forward in the ability to generate text. Examples of autoregressive LLMs include GPT, Llama, Claude and the open-source Mistral.
#
# Foundation models: Prebuilt and curated foundation models can speed the launching of an NLP effort and boost trust in its operation. For example, the IBM® Granite™ foundation models are widely applicable across industries. They support NLP tasks including content generation and insight extraction. Additionally, they facilitate retrieval-augmented generation, a framework for improving the quality of response by linking the model to external sources of knowledge. The models also perform named entity recognition which involves identifying and extracting key information in a text.

# %% [markdown]
# ## How NLP works
# NLP works by combining various computational techniques to analyze, understand and generate human language in a way that machines can process. Here is an overview of a typical NLP pipeline and its steps:
#
# #### Text preprocessing
# NLP text preprocessing prepares raw text for analysis by transforming it into a format that machines can more easily understand. It begins with tokenization, which involves splitting the text into smaller units like words, sentences or phrases. This helps break down complex text into manageable parts. Next, lowercasing is applied to standardize the text by converting all characters to lowercase, ensuring that words like "Apple" and "apple" are treated the same. Stop word removal is another common step, where frequently used words like "is" or "the" are filtered out because they don't add significant meaning to the text. Stemming or lemmatization reduces words to their root form (e.g., "running" becomes "run"), making it easier to analyze language by grouping different forms of the same word. Additionally, text cleaning removes unwanted elements such as punctuation, special characters and numbers that may clutter the analysis.
#
# After preprocessing, the text is clean, standardized and ready for machine learning models to interpret effectively.
#
# #### Feature extraction
# Feature extraction is the process of converting raw text into numerical representations that machines can analyze and interpret. This involves transforming text into structured data by using NLP techniques like Bag of Words and TF-IDF, which quantify the presence and importance of words in a document. More advanced methods include word embeddings like Word2Vec or GloVe, which represent words as dense vectors in a continuous space, capturing semantic relationships between words. Contextual embeddings further enhance this by considering the context in which words appear, allowing for richer, more nuanced representations.
#
# #### Text analysis
# Text analysis involves interpreting and extracting meaningful information from text data through various computational techniques. This process includes tasks such as part-of-speech (POS) tagging, which identifies grammatical roles of words and named entity recognition (NER), which detects specific entities like names, locations and dates. Dependency parsing analyzes grammatical relationships between words to understand sentence structure, while sentiment analysis determines the emotional tone of the text, assessing whether it is positive, negative or neutral. Topic modeling identifies underlying themes or topics within a text or across a corpus of documents. Natural language understanding (NLU) is a subset of NLP that focuses on analyzing the meaning behind sentences. NLU enables software to find similar meanings in different sentences or to process words that have different meanings. Through these techniques, NLP text analysis transforms unstructured text into insights.
#
# #### Model training
# Processed data is then used to train machine learning models, which learn patterns and relationships within the data. During training, the model adjusts its parameters to minimize errors and improve its performance. Once trained, the model can be used to make predictions or generate outputs on new, unseen data. The effectiveness of NLP modeling is continually refined through evaluation, validation and fine-tuning to enhance accuracy and relevance in real-world applications.
#
# Different software environments are useful throughout the said processes. For example, the Natural Language Toolkit (NLTK) is a suite of libraries and programs for English that is written in the Python programming language. It supports text classification, tokenization, stemming, tagging, parsing and semantic reasoning functionalities. TensorFlow is a free and open-source software library for machine learning and AI that can be used to train models for NLP applications. Tutorials and certifications abound for those interested in familiarizing themselves with such tools.

# %% [markdown]
# ## Preprocessing Steps for Natural Language Processing (NLP): A Beginner’s Guide

# %% [markdown]
# 1. Text Cleaning
# 2. Tokenization
# 3. Stopword Removal
# 4. Stemming/Lemmatization
#
# # Difference Between Lemmatization and Stemming
#
# | Feature           | Stemming                         | Lemmatization                      |
# |------------------|----------------------------------|------------------------------------|
# | Definition        | Removes suffixes to get root form | Converts word to its base form (lemma) |
# | Output            | May not be a real word           | Always a valid word                |
# | Technique         | Rule-based (simple heuristics)   | Dictionary-based (uses vocab & morphology) |
# | Example           | "running" → "run" or "runn"      | "running"

# %% [markdown]
# # Understanding Tokenizers in Natural Language Processing (NLP)
#
# ## 🔹 What is Tokenization?
# - Breaking text into smaller units called tokens (words, characters, subwords).
# - Converts human-readable text into model-understandable numeric IDs.
#
# ## 🔹 Why Tokenization is Important
# - Structures raw text.
# - Preserves contextual meaning.
# - Standardizes input for machine learning models.
#
# ---
#
# ## 🔹 Types of Tokenization
#
# ### 1. Word-Based Tokenization
# - **Example**: `"The quick brown fox jumps"` → `['The', 'quick', 'brown', 'fox', 'jumps']`
# - ✅ Easy to implement
# - ❌ Large vocabularies
# - ❌ No semantic similarity between forms (e.g., "run" vs "running")
# - ❌ [UNK] tokens for unknown words
#
# ### 2. Character-Based Tokenization
# - **Example**: `"The"` → `['T', 'h', 'e']`
# - ✅ Small vocabulary
# - ✅ Minimal unknown tokens
# - ❌ High token count
# - ❌ Less semantic meaning
#
# ### 3. Subword Tokenization
# - **Example**: `"Tokenization"` → `['Token', '##ization']`
# - ✅ Efficient vocabulary
# - ✅ Preserves semantic meaning
# - ✅ Fewer unknown tokens
# - 🛠 Used in modern models like BERT, GPT
#
# ---
#
# ## 🔹 Common Subword Algorithms
# - **Byte Pair Encoding (BPE)** – Used in GPT-2
# - **WordPiece** – Used in BERT
# - **SentencePiece** – Used in multilingual models
#
# ---
#
# ## 🔹 How Tokenizers Work
#
# ### Step 1: Tokenization
# ```python
# from transformers import AutoTokenizer
# tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
# tokens = tokenizer.tokenize("Learning tokenization is essential in NLP.")
# print(tokens)
# # ['Learning', 'token', '##ization', 'is', 'essential', 'in', 'N', '##LP', '.']

# %% [markdown]
# ### Key Takeaways
#
#
# - Choose the right tokenizer: Use word-based tokenizers for simple tasks, character-based ones for low-resource languages, and subword tokenizers for balanced performance.
# - Understand the vocabulary: A tokenizer’s vocabulary size impacts both memory usage and semantic coverage.
# - Use pretrained tools: Frameworks like Hugging Face provide ready-to-use tokenizers tailored to specific models.

# %% [markdown]
# ## Key Terms and Concepts in Natural Language Processing
#
# Tokenization: Splitting text into individual words, phrases, symbols, or other meaningful elements called tokens. This is an essential first step for processing text.
#
# Stop words: Common words like “a”, “and”, “the” that provide little informational value. Stop words are often filtered out before processing text.
#
# Stemming: Reducing words to their root form. For example, “learning” is reduced to “learn”. This helps consolidate vocabulary and reduce sparsity.
#
# Lemmatization: Similar to stemming but produces valid lemmas or dictionary roots. For example, “better” becomes “good” rather than just removing suffixes.
#
# Bag-of-words: A representation of text that describes the occurrence of words within a document. The order of words is ignored.
#
# N-grams: Sequences of n consecutive words used to understand word order and local context. For example, “artificial intelligence” becomes a 2-gram.
#
# POS tagging: Assigning parts of speech (like noun, verb, adjective) to tokens in text. Useful for disambiguation.
#
# Named entity recognition: Identifying and classifying key entities (like people, places, organizations) in text. Essential for understanding meaning.
#
# Word embeddings: Representing each word as a high-dimensional numeric vector that encodes semantic meaning based on word usage. Enables mathematical operations.
#
# Corpus: Collection of texts used for NLP analysis.
#
# Syntax: Structure and grammar of sentences.
#
# Semantics: Meaning of language.
#
# Sentiment analysis: Identifying emotional tone behind text, like opinions, emotions, attitudes in text.
#
# Named entity recognition: Finding and labeling entities like people, places.
#
# Parsing: Analyzing sentence structure and relationship between words.
#
# Co-reference resolution: Linking words or phrases that refer to the same entity.
#
# Word sense disambiguation: Determining meaning of ambiguous words based on context.
#
# Machine translation: Automated translation between languages.
#
# Question answering: Systems that answer questions based on knowledge.
#
# Dialog systems: Automated conversational agents (chatbots).
#
# Spell correction: Spell correction identifies and automatically corrects misspellings in text using dictionaries or language models.
#
# Optical character recognition (OCR): OCR converts images of text into machine-readable data, enabling text extraction from scanned documents, images, and videos.
#
# Natural language generation: Natural language generation (NLG) creates textual content from data, aiming to produce coherent and contextually appropriate sentences.
#
# Contextual embeddings: Contextual embeddings represent words in their surrounding context, enabling richer semantic understanding. Models like BERT and ELMo achieve this by learning from text.
#
# Language models: Language models learn language structure and generate probable sequences of words. Examples include GPT-3, which can generate human-like text based on input prompts.
#
# Probabilistic models: Probabilistic models use statistical methods and probabilities to model language, allowing for handling uncertainty in text data.
#
# Linguistic rules: Linguistic rules encode grammar structures, morphology, and syntax into algorithms for language processing.
#
# Ontologies: Ontologies are structured representations of concepts and relationships, often used to model knowledge and support semantic understanding.
#
# Speech recognition: Speech recognition converts spoken language to text, enabling voice command and transcription applications.
#
# Natural language understanding: Natural language understanding (NLU) derives meaning from text, interpreting user intents and making sense of linguistic input.
#
# Discourse analysis: Discourse analysis studies language use in conversations and texts to understand how sentences and paragraphs connect to convey meaning.
#
# Coreference: Determining when multiple expressions refer to the same entity.
#
# Knowledge graphs: Knowledge graphs represent interconnected entities and concepts as a graph data model, often used in information retrieval and knowledge management.
#
# Sequence-to-sequence models: Sequence-to-sequence models process both input and output sequences, used in tasks like translation, where the model transforms a source sequence into a target sequence.
#
# Language vectors: Language vectors represent words or sentences as numerical vectors capturing semantics, allowing for mathematical operations like similarity calculations.
#
# Transducers: Transducers are models that process input sequentially while producing output, useful for tasks like speech recognition and translation.
#
# Morphology: Morphology studies the internal structure of words and how words are formed, including how roots, prefixes, and suffixes combine.
#
# Phonology: Phonology examines the sound systems of languages, including phonemes and how they are organized and used.
#
# Pragmatics: Pragmatics explores how context and intent influence language understanding, including how meaning changes based on context.
#
# Discourse: Discourse involves connected language across multiple sentences or conversations, providing context for understanding longer texts.
#
# Anaphora/Cataphora: Anaphora and cataphora involve linking pronouns or nouns back (anaphora) or forward (cataphora) to other words or phrases for clarity.
#
# Topic modeling: Discovering abstract topics in a collection of documents.
#
# Information extraction: Extracting structured info like entities, relationships, events from text.
#
# Summarization: Generating a summary capturing the main points of a larger text.
#
# Question generation: Automatically creating questions from passages of text.
#
# Coreference resolution: Determining when two expressions refer to the same entity.
#
# Word sense disambiguation: Identifying the correct sense of ambiguous words.
#
# Optical character recognition: Converting images of text into machine-readable text.
#
# Multimodal learning: Combining language with other modes like vision or speech.
#
# Phonetics: The study of speech sounds and pronunciation.
#
# Phonology: The study of the sound systems of languages.
#
# Morphophonology: Studying how morphology interacts with phonology.
#
# Sociolinguistics: Studying language in social contexts.
#
# Forensic linguistics: Forensic linguistics applies linguistic analysis in legal contexts, aiding in areas such as authorship attribution and linguistic profiling.
#
# Psycholinguistics: Psycholinguistics studies the psychological processes of language use, including how language is acquired, comprehended, and produced.
#
# Neurolinguistics: Neurolinguistics examines the neuroscience of language processing in the brain, exploring how language and cognition are connected.
#
# Stylistics: Stylistics analyzes and understands linguistic style, exploring how language is used to create tone, mood, and impact.
#
# Readability: Measuring how easy a text is to read and understand.
#
# Text simplification: Reducing complexity of text to make it more readable.
#
# Code-switching: Code-switching involves switching between languages or dialects in speech or writing, often reflecting bilingual or multilingual speakers’ linguistic flexibility.
#
# Multiword expressions: Words that act as a single semantic unit like “case study”.
#
# Evaluation metrics: Ways to quantitatively evaluate NLP systems like BLEU, ROUGE.
#
# Low resource languages: Low-resource languages have limited digital data available, making NLP tasks more challenging due to the lack of training resources.

# %% [markdown]
# # Basic Text Representation in NLP
#
# ## Topics Covered
#
# ### Overview
# The first ever instructions which might have been fed to a computer were numerical. We already know that a computer is brilliant with numbers and has replaced the calculator. But did you know that they have replaced human jobs such as a call center agent or an assistant as well?
# The development in the field of computers has been going on for decades, and there is still a lot left to discover. But how can a computer understand and react to human language? How do you open the Google app and ask a question, and get the answers right away?
# All of this is possible because of the field of artificial intelligence called **Natural Language Processing (NLP)**. This connects computers to human language by processing text, speech, and voice.
#
# Text data is integral to NLP and is readily available. We need to convert this data into a form that the computer can understand. This is basic text representation in NLP.
#
# ---
#
# ## Introduction
# The raw text corpus is preprocessed and transformed into a number of text representations that are input to the machine learning model.
# The data is pushed through a series of preprocessing tasks such as:
# - Tokenization
# - Stopword removal
# - Punctuation removal
# - Stemming
# and many more.
#
# We clean the data of any noise present. This cleaned data is represented in various forms according to the purpose of the application and the input requirements of the machine learning model.
#
# ---
#
# ## Common Terms Used While Representing Text in NLP
# - **Corpus (C)**: All the text data or records of the dataset together.
# - **Vocabulary (V)**: All the unique words present in the corpus.
# - **Document (D)**: One single text record of the dataset.
# - **Word (W)**: The words present in the vocabulary.
#
# ---
#
# ## Types of Text Representation in NLP
#
# Text representation can be classified into two types:
# 1. **Discrete text representation**
# 2. **Distributed text representation**
#
# - **Discrete text representation**: The individual words in the corpus are mutually exclusive and independent of one another.
#   _Example_: One Hot Encoding.
#
# - **Distributed text representation**: Depends on co-dependence of words.
#   _Example_: Word Embeddings.
#
# > This article focuses on the **discrete** text representation in NLP.
#
# ---
#
# ### 🟠 One Hot Encoding
#
# Each word in a text corpus is assigned a vector with 0 and 1.
# This is called a **one-hot vector**, and it uniquely identifies each word.
# The vector contains a single `1` in the position corresponding to the word’s index in the vocabulary. All other entries are 0.
#
# > The size of this one-dimensional vector is equal to the vocabulary size.
#
# #### 🧠 Note:
# If the same word appears multiple times with different casing (e.g. “The” and “the”), they will be treated as different tokens unless lowercasing is applied.
#
# #### 🧮 Output Shape:
# If sentence length = `p` and vocabulary size = `q`, the encoded sentence has shape `(p, q)`.
#
# #### 🔻 Drawback:
# One-hot vectors are **sparse** and **scalability becomes an issue** with large vocabularies.
#
# #### ✅ Advantages:
# - Easy to understand and implement
#
# #### ❌ Disadvantages:
# - High sparsity
# - Different document lengths = different vector sizes
# - Does not capture semantics
#
# ---
#
# ### 🔧 One-hot encoding using `sklearn`
#
# ```python
# from sklearn.preprocessing import OneHotEncoder
# import itertools
#
# document = ["The", "boy", "sat", "on", "the", "floor"]
# tokens = [doc.split(" ") for doc in document]
# token_chain = itertools.chain.from_iterable(tokens)
# word_to_id = {token: idx for idx, token in enumerate(set(token_chain))}
# token_ids = [[word_to_id[token] for token in toke] for toke in tokens]
#
# vec = OneHotEncoder(categories="auto")
# V = vec.fit_transform(token_ids)
# print(V.toarray())
# ```
#
# ---
#
# ### 🟡 Bag of Words (BoW)
#
# This converts a **whole document** into a **fixed-length vector** using word **frequency**.
#
# > It helps in comparing documents based on their content.
#
# #### ✅ Advantages:
# - Simple and effective
# - Frequency gives word importance
# - Vector size = dictionary size
#
# #### ❌ Disadvantages:
# - No semantic meaning
# - No positional info
# - High-frequency ≠ highest importance
#
# ---
#
# ### 🔧 Bag of Words using `CountVectorizer`
#
# ```python
# from sklearn.feature_extraction.text import CountVectorizer
# document = ["NLP has changed the world. I love NLP. NLP is cool"]
# vectorizer = CountVectorizer()
# vectorizer.fit(document)
# print(vectorizer.vocabulary_)
# vector = vectorizer.transform(document)
# print(vector.toarray())
# ```
#
# **Output:**
# ```python
# {'nlp': 5, 'has': 2, 'changed': 0, 'the': 6, 'world': 7, 'love': 4, 'is': 3, 'cool': 1}
# [[1 1 1 1 1 3 1 1]]
# ```
#
# ---
#
# ### 🟢 TF-IDF (Term Frequency – Inverse Document Frequency)
#
# Improves upon CountVectorizer by penalizing both **common** and **rare** words.
#
# #### 🔹 Term Frequency (TF)
#
# TF measures how often a term appears in a specific document.
#
# $$
# tf(t, d) = \frac{\text{count of term } t \text{ in } d}{\text{total terms in } d}
# $$
#
# - **t**: the term (word)
# - **d**: the document
# - **tf(t, d)**: frequency of term *t* in document *d*
# - Result is higher if the term appears frequently in the document.
#
# ---
#
# #### 🔹 Inverse Document Frequency (IDF)
#
# IDF measures how important a term is across the **entire corpus**. Rare terms across documents have higher IDF.
#
# $$
# idf(t) = \log \left( \frac{N}{df + 1} \right)
# $$
#
# - **N**: total number of documents
# - **df**: number of documents containing the term *t*
# - Adding 1 to avoid division by zero
# - Result is higher for rare terms, lower for common ones
#
# ---
#
# #### 🔹 TF-IDF (Term Frequency–Inverse Document Frequency)
#
# Combines TF and IDF to score how important a word is to a document **relative to the corpus**.
#
# $$
# tf\_idf(t, d) = tf(t, d) \times idf(t)
# $$
#
# - High when:
#   - The term appears frequently in the document (high TF)
#   - The term appears in few other documents (high IDF)
# - Low when:
#   - The term is common across all documents (low IDF)
#
#
#
# #### ✅ Advantages:
# - Weights words based on relevance
# - Balances term importance
#
# #### ❌ Disadvantages:
# - No word position
# - No semantic meaning
#
# ---
#
# ### 🔧 TF-IDF using `TfidfVectorizer`
#
# ```python
# from sklearn.feature_extraction.text import TfidfVectorizer
# text = ['NLP has changed the world', 'I love NLP', 'NLP is cool', 'NLP is future']
# tf = TfidfVectorizer()
# txt_fit = tf.fit(text)
# txt_transform = txt_fit.transform(text)
# idf = tf.idf_
# print(dict(zip(txt_fit.get_feature_names_out(), idf)))
# ```
#
# **Output:**
# ```python
# {'changed': 1.91, 'cool': 1.91, 'future': 1.91, 'has': 1.91, 'is': 1.51, 'love': 1.91, 'nlp': 1.0, 'the': 1.91, 'world': 1.91}
# ```
#
# ---
#
# ### 🔵 N-grams
#
# Like BoW, but captures **groups of words** (bigrams, trigrams).
#
# > This helps understand context and improves semantic richness.
#
# - **Bigram**: 2-word combinations
# - **Trigram**: 3-word combinations
#
# ### 🔧 N-gram using `CountVectorizer`
#
# ```python
# from sklearn.feature_extraction.text import CountVectorizer
# text = ['NLP has changed the world', 'I love NLP', 'NLP is cool', 'NLP is future']
# cv = CountVectorizer(ngram_range=(2,2))
# X = cv.fit_transform(text)
# print(cv.get_feature_names_out())
# print(X.toarray())
# ```
#
# ---
#
# ### 📌 Summary
#
# | Representation     | Pros                              | Cons                                |
# |--------------------|-----------------------------------|-------------------------------------|
# | One Hot Encoding   | Simple to implement               | Sparse, no semantics, not scalable |
# | Bag of Words       | Frequency-based, simple           | No semantics, no position info      |
# | TF-IDF             | Better weighting of words         | Still no semantics                  |
# | N-grams            | Captures local context            | Still limited semantic capture      |
#
# ---

# %%
from sklearn.feature_extraction.text import CountVectorizer
document = ["NLP has changed the world. I love NLP. NLP is cool"]
vectorizer = CountVectorizer()
# tokenize and build vocabulary
vectorizer.fit(document)
print(vectorizer.vocabulary_)
# encode document
vector = vectorizer.transform(document)
# summarize encoded vector
print(vector.toarray())
# Out:
# {'nlp': 5, 'has': 2, 'changed': 0, 'the': 6, 'world': 7, 'love': 4, 'is': 3, 'cool': 1}
# [[1 1 1 1 1 3 1 1]]

# %% [markdown]
# n the above code, you can see that NLP with index 5 has a count 3. The frequency can also denote the weightage of a word in a sentence. These weights can be leveraged for different types of analysis and used for training ML models.

# %% [markdown]
# TF-IDF
#
# This representation of text in NLP overcomes some of the drawbacks of CountVectorizer. There is a need to suppress high-frequency words and ignore very low-frequency words so that we can normalize the weights. The word which appears multiple times in a document and rarely in the corpus should have a good weightage. This weightage is calculated using two formulas:- Term Frequency and Inverse Document Frequency.
#
# - Term Frequency: The ratio of the number of occurrences of a word in a document to the number of terms in the document is called term frequency.
#
# "t" is the term and "d" is the number of terms in the .document The tf of the word "love" in the sentence "I love nlp" is 1/3.
#
# - Inverse document frequency: Idf of a term is the log of the ratio of the number of documents in the corpus to the number of documents with the term in them.
