# %%
import cv2
import os

# === CONFIG ===
video_path = r"D:/arc-2025/arc/ai/Uddav-Rajbhandari/Object detection/data video/video.mp4"
output_folder = "frames_to_upload"
frame_interval = 30  # save every 30th frame

# === CREATE FOLDER ===
os.makedirs(output_folder, exist_ok=True)

# === OPEN VIDEO ===
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    raise IOError(f"Could not open video file: {video_path}")
else:
    print(f"Successfully opened: {video_path}")
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")

frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Finished reading video.")
        break

    if frame_count % frame_interval == 0:
        filename = f"frame_{saved_count:04d}.jpg"
        filepath = os.path.join(output_folder, filename)
        cv2.imwrite(filepath, frame)
        saved_count += 1

    frame_count += 1

cap.release()
print(f"Saved {saved_count} frames to '{output_folder}'")
# Out:
# Successfully opened: D:/arc-2025/arc/ai/Uddav-Rajbhandari/Object detection/data video/video.mp4
# Total frames in video: 2002
# Finished reading video.
# Saved 67 frames to 'frames_to_upload'
