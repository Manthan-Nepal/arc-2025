# %% [markdown]
# ## Movie Recommendation System Based on Collaborative Filtering

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
user_ratings_df = pd.read_csv("ratings.csv")
user_ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
movie_metadata = pd.read_csv("movies.csv")
movie_metadata.head()
# movie_metadata = movie_metadata[['title', 'genres']]
# movie_metadata.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#combine these dataframes on the common column movieID
movie_data = user_ratings_df.merge(movie_metadata, on='movieId')
movie_data.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
#
#                                               title  \
# 0                               Pulp Fiction (1994)
# 1  Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2  Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3                                Underground (1995)
# 4                        Singin' in the Rain (1952)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1                        Drama
# 2                        Drama
# 3             Comedy|Drama|War
# 4       Comedy|Musical|Romance

# %%
#User-Item Matrix
user_item_matrix = user_ratings_df.pivot(index=['userId'], columns=['movieId'], values='rating').fillna(0)
user_item_matrix
# Out:
# /tmp/ipykernel_17638/1263333150.py:2: PerformanceWarning: The following operation may generate 9597558427 cells in the resulting pandas object.
#   user_item_matrix = user_ratings_df.pivot(index=['userId'], columns=['movieId'], values='rating').fillna(0)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 #User-Item Matrix
# ----> 2 user_item_matrix = user_ratings_df.pivot(index=['userId'], columns=['movieId'], values='rating').fillna(0)
#       3 user_item_matrix
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# ...
